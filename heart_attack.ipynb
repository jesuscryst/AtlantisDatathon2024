# %%
import pandas as pd

# %%
heart_attack = pd.read_csv("heart_attack_dataset.csv")
heart_attack = heart_attack.drop(columns=["Troponin", "CK-MB"], axis="columns")
# Out:
#       Age  Gender  Heart rate  Systolic blood pressure  \
# 0      63       1          66                      160
# 1      20       1          94                       98
# 2      56       1          64                      160
# 3      66       1          70                      120
# 4      54       1          64                      112
# ...   ...     ...         ...                      ...
# 1314   44       1          94                      122
# 1315   66       1          84                      125
# 1316   45       1          85                      168
# 1317   54       1          58                      117
# 1318   51       1          94                      157
#
#       Diastolic blood pressure  Blood sugar    Result
# 0                           83        160.0  negative
# 1                           46        296.0  positive
# 2                           77        270.0  negative
# 3                           55        270.0  positive
# 4                           65        300.0  negative
# ...                        ...          ...       ...
# 1314                        67        204.0  negative
# 1315                        55        149.0  positive
# 1316                       104         96.0  positive
# 1317                        68        443.0  positive
# 1318                        79        134.0  positive
#
# [1319 rows x 7 columns]

# %%
heart_attack_pred = pd.read_csv("heart_attack_prediction_dataset.csv")
heart_attack_pred = heart_attack_pred.drop(columns=["Patient ID", "Country", "Continent", "Hemisphere"])

medical_insurance = pd.read_csv("medical_insurance.csv")
medical_insurance.rename(columns={'age': 'Age'}, inplace = True)

df = heart_attack.merge(heart_attack_pred, on="Age").merge(medical_insurance, on="Age")
df

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=5573c15e-87ef-4f02-8145-fd5408829827' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
