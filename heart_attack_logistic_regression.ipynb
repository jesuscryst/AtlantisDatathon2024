# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
heart_attack_pred = pd.read_csv("heart_attack_prediction_dataset.csv").drop(columns=["Patient ID", "Country", "Continent", "Hemisphere"])
heart_attack_pred.columns = map(str.lower, heart_attack_pred)
# heart_attack_pred.head()

# %%
medical_insurance = pd.read_csv("medical_insurance.csv")
medical_insurance['bmi'] = round(medical_insurance['bmi'])
# medical_insurance.head()

# %%
heart_attack_pred['sex'] = heart_attack_pred['sex'].str.lower()
# df = heart_attack_pred.merge(medical_insurance, on=['age', 'sex', 'bmi'])
# df.head()

# %%
heart_attack_pred['bmi'] = round(heart_attack_pred['bmi'])
heart_attack_pred[['systolic blood pressure', 'diastolic blood pressure']] = heart_attack_pred['blood pressure'].str.split('/', expand=True)
heart_attack_pred = heart_attack_pred.drop(columns=['blood pressure', 'physical activity days per week'])
heart_attack_pred['systolic blood pressure'] = pd.to_numeric(heart_attack_pred['systolic blood pressure'])
heart_attack_pred['diastolic blood pressure'] = pd.to_numeric(heart_attack_pred['diastolic blood pressure'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 heart_attack_pred['bmi'] = round(heart_attack_pred['bmi'])
#       2 heart_attack_pred[['systolic blood pressure', 'diastolic blood pressure']] = heart_attack_pred['blood pressure'].str.split('/', expand=True)
#       3 heart_attack_pred = heart_attack_pred.drop(columns=['blood pressure', 'physical activity days per week'])
#
# NameError: name 'heart_attack_pred' is not defined

# %%
# Import label encoder 
from sklearn import preprocessing 
# label_encoder object knows  
# how to understand word labels. 
label_encoder = preprocessing.LabelEncoder() 
  
# Encode labels in column 'species'. 
heart_attack_pred['sex']= label_encoder.fit_transform(heart_attack_pred['sex']) 
  
heart_attack_pred['sex'].unique() 
heart_attack_pred['diet']= label_encoder.fit_transform(heart_attack_pred['diet']) 
  
heart_attack_pred['diet'].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 8
#       5 label_encoder = preprocessing.LabelEncoder()
#       7 # Encode labels in column 'species'.
# ----> 8 heart_attack_pred['sex']= label_encoder.fit_transform(heart_attack_pred['sex'])
#      10 heart_attack_pred['sex'].unique()
#      11 heart_attack_pred['diet']= label_encoder.fit_transform(heart_attack_pred['diet'])
#
# NameError: name 'heart_attack_pred' is not defined

# %%
heart_attack_pred.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 heart_attack_pred.head()
#
# NameError: name 'heart_attack_pred' is not defined

# %%
corr = heart_attack_pred.corr()
ax = sns.heatmap(
    corr,
    vmin = -1, vmax = 1, center = 0,
    cmap = sns.diverging_palette(20,220, n = 200),
    square = True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 corr = heart_attack_pred.corr()
#       2 ax = sns.heatmap(
#       3     corr,
#       4     vmin = -1, vmax = 1, center = 0,
#       5     cmap = sns.diverging_palette(20,220, n = 200),
#       6     square = True
#       7 )
#       8 ax.set_xticklabels(
#       9     ax.get_xticklabels(),
#      10     rotation=45,
#      11     horizontalalignment='right'
#      12 )
#
# NameError: name 'heart_attack_pred' is not defined

# %%
heart_attack_pred.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 heart_attack_pred.dtypes
#
# NameError: name 'heart_attack_pred' is not defined

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
bmi_vs_heart = df.groupby('bmi', as_index=False)['heart attack risk'].mean()
print(type(bmi_vs_heart))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 bmi_vs_heart = df.groupby('bmi', as_index=False)['heart attack risk'].mean()
#       2 print(type(bmi_vs_heart))
#
# NameError: name 'df' is not defined

# %%
bmi_vs_heart.plot.scatter(x='bmi', y='heart attack risk', alpha=0.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 bmi_vs_heart.plot.scatter(x='bmi', y='heart attack risk', alpha=0.5)
#       2 plt.show()
#
# NameError: name 'bmi_vs_heart' is not defined

# %%
bmi_vs_heart.plot.bar(x='bmi', y='heart attack risk', alpha=0.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 bmi_vs_heart.plot.bar(x='bmi', y='heart attack risk', alpha=0.5)
#       2 plt.show()
#
# NameError: name 'bmi_vs_heart' is not defined

# %%
# plotting BMI vs Blood Pressure
df['systolic blood pressure'] = pd.to_numeric(df['systolic blood pressure'])
bmi_vs_bloodpressure = df.groupby('bmi', as_index=False)['systolic blood pressure'].mean()
bmi_vs_bloodpressure
bmi_vs_bloodpressure.plot.scatter(x = 'bmi', y = 'systolic blood pressure', alpha = 0.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # plotting BMI vs Blood Pressure
# ----> 2 df['systolic blood pressure'] = pd.to_numeric(df['systolic blood pressure'])
#       3 bmi_vs_bloodpressure = df.groupby('bmi', as_index=False)['systolic blood pressure'].mean()
#       4 bmi_vs_bloodpressure
#
# NameError: name 'pd' is not defined

# %%
# plotting BMI vs Cholesterol 
bmi_vs_cholesterol = df.groupby('bmi', as_index=False)['cholesterol'].mean()
bmi_vs_cholesterol.plot.scatter(x = 'bmi', y = 'cholesterol', alpha = 0.5)
plt.show()

# %%
# Age and Mean of Risk
age_groups = {
    '10-19': (10, 19),
    '20-29': (20, 29),
    '30-39': (30, 39),
    '40-49': (40, 49),
    '50-59': (50, 59),
    '60+': (60, float('inf'))
}

count_groups = {group: 0 for group in age_groups}

for i in df["age"]:
    for group, (start, end) in age_groups.items(): 
        if start <= i <= end:
            count_groups[group] += 1

print(count_groups)

age_vs_heart = df.groupby(count_groups, as_index=False)['heart attack risk'].mean()
age_vs_heart.plot.scatter(x='age', y='heart attack risk', alpha=0.5)
plt.show()

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=5573c15e-87ef-4f02-8145-fd5408829827' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
